# %% [markdown]
# <a href="https://colab.research.google.com/github/MetalHeadv3/In-yniera-Big-data-walidacja/blob/main/Zad1_Big_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('zamowienia.csv')

print("Typy danych (domyślne):")
print(df.dtypes)

mem_default = df.memory_usage(deep=True).sum() / (1024 ** 2)
print(f"RAM (domyślne typy): {mem_default:.2f} MB")
# Out:
# Typy danych (domyślne):
# Kraj;Sprzedawca;Data zamowienia;idZamowienia;Utarg    object
# dtype: object
# RAM (domyślne typy): 0.07 MB
